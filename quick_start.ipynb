# %% [markdown]
# # 快速开始
# 本 notebook 提供一个简单的演示，介绍如何使用预训练的 GCDM 模型生成分子结构。
#
# ## 环境准备
# 请确保已按照项目 README 中的说明创建并激活 conda 环境，并下载所需的预训练模型文件。
#
# ```bash
# conda activate bio-diffusion
# ```
#
# ## 生成分子示例
# 以下代码将调用项目中的脚本生成一批分子示例。运行本段代码需在项目根目录下执行。

# %%
# 生成 QM9 分子样本
# !bash scripts/science_demo_qm9.sh
